# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import simpleRNN, Dense

# %%
X = np.array([
    [[1], [2], [3]],
    [[2], [3], [4]],
    [[3], [4], [5]],
    [[4], [5], [6]]
])

y = np.array([4, 5, 6, 7])
model = Sequential([
    SimpleRNN(32, input_shape=(3,1), activation='tanh'),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse'
)

model.fit(X,y, epochs=1000, verbose=1)

test = np.array([[[5], [6], [7]]])
prediction= model.predict(test)

print("prediction", prediction)
