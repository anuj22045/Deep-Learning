# %%
import tensorflow as tf
# print(tf.__version__)

#create your tensor 
matrix = tf.constant([
    [1,2],
    [3,4]
])

print(matrix)
print(matrix.dtype)

#find dimensions
print(matrix.ndim)

# print(matrix.numpy())
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)
# <dtype: 'int32'>
# 2
# [[1 2]
#  [3 4]]
